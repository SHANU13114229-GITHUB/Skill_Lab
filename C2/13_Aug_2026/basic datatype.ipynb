# %%
#Numerical type
p = 125
print(p + 25)
print(p // 10)
print(p % 10)
print(2 ** 8)
# Out:
# 150
# 12
# 5
# 256

# %%
# float 
M = 12.75
print(round(M, 1))  #12.8
print(abs(-3.5))
# Out:
# 12.8
# 3.5

# %%
# complex
z = 3 + 4j
print(z.real)
print(z.imag)
