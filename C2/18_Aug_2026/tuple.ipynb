# %%
#Tuple
a = (type(20),50,80,110,"Shanu",type("Adarsh"),type(True))
print(type(a))
# Out:
# <class 'tuple'>

# %%
print(a)
# Out:
# (<class 'int'>, 50, 80, 110, 'Shanu', <class 'str'>, <class 'bool'>)

# %%
for i in range (20,70,20):
    print(i)
# Out:
# 20
# 40
# 60

# %%
d = tuple(range(2,60,3))
print(d)
print(d[:10])
print(type(d))
print(d)
# Out:
# (2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59)
# (2, 5, 8, 11, 14, 17, 20, 23, 26, 29)
# <class 'tuple'>
# (2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59)

# %%
a = 12,43,43,53
b = 73,34,63,83
c = a+b
print(c)
print(type(c))
print(len(a))
print(len(c))
print(a.count(43))
print(c.index(73))
print(63 in c)
print(sorted(c))
# Out:
# (12, 43, 43, 53, 73, 34, 63, 83)
# <class 'tuple'>
# 4
# 8
# 2
# 4
# True
# [12, 34, 43, 43, 53, 63, 73, 83]

# %%
tup = tuple(input("Enter Tuple : "))
for i in tup:
    sum = tup+i
    avg = sum / len(tup)
    print("Sum = ",sum)
    print("Avg = ",avg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 tup = tuple(input("Enter Tuple : "))
#       2 for i in tup:
# ----> 3     sum = tup+i
#       4     avg = sum / len(tup)
#       5     print("Sum = ",sum)
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %%
a = eval(input("Enter number : "))
sum = 0
for x in a:
